# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mobile = pd.read_csv('Mobile phone price.csv')
mobile
# Out:
#        Brand              Model Storage    RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2    OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4     Google            Pixel 6   128 GB   8 GB                  6.4
# ..       ...                ...      ...    ...                  ...
# 402  Samsung   Galaxy Note20 5G      128      8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128      6                 6.57
# 404    Apple  iPhone 12 Pro Max      128      6                  6.7
# 405     Oppo              Reno3      128      8                  6.4
# 406  Samsung    Galaxy S10 Lite      128      6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh) Price ($)
# 0          12 + 12 + 12                    3095       999
# ...

# %%
mobile.isnull().any()
# Out:
# Brand                     False
# Model                     False
# Storage                   False
# RAM                       False
# Screen Size (inches)      False
# Camera (MP)               False
# Battery Capacity (mAh)    False
# Price ($)                 False
# dtype: bool

# %%
mobile.duplicated().any()
# Out:
# True

# %%
mobile[mobile.duplicated()]
# Out:
#         Brand                  Model Storage   RAM  Screen Size (inches)  \
# 45      Apple         iPhone 12 Mini    64 GB  4 GB                  5.4
# 61     Xiaomi         Poco M3 Pro 5G    64 GB  4 GB                  6.5
# 132     Nokia                   XR20    128GB   6GB                 6.67
# 170  Motorola       Moto G Stylus 5G    128GB   5GB                  6.8
# 195      Oppo                 A74 5G    128GB   6GB                  6.5
# 221      Vivo                   Y12s     32GB   3GB                 6.51
# 229    Xiaomi  Redmi Note 10 Pro Max    128GB   8GB                 6.67
# 240     Nokia               C20 Plus     32GB   3GB                  6.5
# 246    Xiaomi            Poco X3 Pro    128GB   6GB                 6.67
# 248      Oppo                    A16     32GB   3GB                 6.52
# 260      Vivo                   Y12s     32GB   3GB                 6.51
# 282   Samsung             Galaxy A12     64GB   4GB                  6.5
# ...

# %%
mobile.drop_duplicates(inplace = True)

# %%
mobile.duplicated().sum()
# Out:
# 0

# %%
mobile.reset_index(drop=True, inplace=True)

# %%
mobile.columns
# Out:
# Index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)'],
#       dtype='object')

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   381 non-null    object
#  1   Model                   381 non-null    object
#  2   Storage                 381 non-null    object
#  3   RAM                     381 non-null    object
#  4   Screen Size (inches)    381 non-null    object
#  5   Camera (MP)             381 non-null    object
#  6   Battery Capacity (mAh)  381 non-null    int64
#  7   Price ($)               381 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 23.9+ KB

# %%
mobile.describe()
# Out:
#        Battery Capacity (mAh)
# count              381.000000
# mean              4683.958005
# std                792.927831
# min               1821.000000
# 25%               4300.000000
# 50%               5000.000000
# 75%               5000.000000
# max               7000.000000

# %%
mobile['Brand'].unique()
# Out:
# array(['Apple', 'Samsung', 'OnePlus', 'Xiaomi', 'Google', 'Oppo', 'Vivo',
#        'Realme', 'Motorola', 'Nokia', 'Sony', 'LG', 'Asus', 'Blackberry',
#        'CAT', 'Huawei'], dtype=object)

# %%
plt.figure(figsize=(16,5))
ax = sns.countplot(x=mobile['Brand'])
for container in ax.containers:
    ax.bar_label(container, fmt = '%.0f', label_type = 'edge', padding = 3)
plt.grid()

plt.show()

# %%
mobile['Brand'].value_counts()
# Out:
# Brand
# Samsung       73
# Xiaomi        62
# Oppo          53
# Realme        43
# Vivo          33
# Apple         28
# Nokia         24
# Motorola      22
# OnePlus       14
# Huawei        12
# Google         5
# Asus           4
# LG             3
# Blackberry     3
# Sony           1
# CAT            1
# Name: count, dtype: int64

# %%
mobile['Model'].unique()
# Out:
# array(['iPhone 13 Pro', 'Galaxy S21 Ultra', '9 Pro', 'Redmi Note 10 Pro',
#        'Pixel 6', 'iPhone 13', 'Galaxy Z Flip3', 'Poco X3 Pro',
#        'Reno6 Pro+ 5G', 'X70 Pro+', 'Nord CE 5G', 'Galaxy A52s 5G',
#        'GT Neo2', 'iPhone 12 Mini', 'Find X3 Pro', 'Mi 11 Lite 5G NE',
#        'Galaxy S21', 'Y20s (G)', '8s 5G', 'A94', 'Redmi 10 Prime',
#        'Galaxy A22 5G', 'Narzo 50 Pro 5G', '9', 'Redmi Note 10 Pro Max',
#        'iPhone 11', 'Galaxy A03s', 'A74 5G', 'Y12s (2021)', '9i',
#        'Galaxy M52 5G', 'Redmi 10', 'iPhone SE (2nd Gen)', 'A53s', 'Y33s',
#        'C25s', 'Galaxy A22 4G', 'Nord 2 5G', 'Poco M3 Pro 5G',
#        'iPhone XR', 'A16', 'C21Y', 'Galaxy F22', 'F19 Pro+ 5G', 'Mi 11X',
#        'V21e', '8 5G', 'Galaxy M12', 'A16s', 'Redmi 9 Power',
#        'iPhone 11 Pro Max', 'Y20G', 'Narzo 50i', 'A54', 'Redmi 9T',
#        'iPhone 13 Pro Max', 'Y33', 'Galaxy A72', 'Reno6 Pro 5G',
#        'iPhone SE (2020)', 'Y53s', '7i', 'Galaxy A52 5G', 'F19 Pro',
# ...

# %%
mobile['Model'].nunique()
# Out:
# 239

# %%
mobile['Storage '].unique()
# Out:
# array(['128 GB', '256 GB', '64 GB', '32 GB', '128GB', '256GB', '64GB',
#        '32GB', '256', '64', '128', '512', '32'], dtype=object)

# %%
mobile.rename(columns = {"Storage ": "Storage"}, inplace = True)

# %%
mobile.columns
# Out:
# Index(['Brand', 'Model', 'Storage', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)'],
#       dtype='object')

# %%
mobile['Storage'].unique()
# Out:
# array(['128 GB', '256 GB', '64 GB', '32 GB', '128GB', '256GB', '64GB',
#        '32GB', '256', '64', '128', '512', '32'], dtype=object)

# %%
mobile['Storage'] = mobile['Storage'].str.replace(" GB", "").str.replace("GB", "")

# %%
mobile['Storage'].unique()
# Out:
# array(['128', '256', '64', '32', '512'], dtype=object)

# %%
mobile['RAM '].unique()
# Out:
# array(['6 GB', '12 GB', '8 GB', '4 GB', '3 GB', '2 GB', '4GB', '8GB',
#        '6GB', '12GB', '3GB', '2GB', '5GB', '12', '3', '6', '8', '4', '16',
#        '2'], dtype=object)

# %%
mobile.rename(columns = {"RAM ": "RAM"}, inplace = True)

# %%
mobile['RAM'] = mobile['RAM'].str.replace(" GB", "").str.replace("GB", "")

# %%
mobile['RAM'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 mobile['RAM'].unique().value_counts()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
mobile['Screen Size (inches)'].unique()
# Out:
# array(['6.1', '6.8', '6.7', '6.67', '6.4', '6.55', '6.78', '6.43', '6.5',
#        '6.62', '5.4', '6.2', '6.51', '6.6', '4.7', '6.58', '6.52', '6.44',
#        '6.53', '6.56', '6.8 + 3.9', '4.5', '6.39', '5.9', '5.5', '6.81',
#        '5.99', '6.82', '6.3', '6.22', '6', '6.35', '6.9', '6.76', '6.49',
#        '6.72', '5.7', '6.47', '7.6 (unfolded)', '6.15', '6.57'],
#       dtype=object)

# %%
mobile['Camera (MP)'].unique()
# Out:
# array(['12 + 12 + 12', '108 + 10 + 10 + 12', '48 + 50 + 8 + 2',
#        '64 + 8 + 5 + 2', '50 + 12.2', '12 + 12', '48 + 8 + 2 + 2',
#        '50 + 13 + 16 + 2', '50 + 48 + 12 + 8', '64 + 8 + 2',
#        '64 + 12 + 5 + 5', '50 + 50 + 13 + 3', '64 + 8 + 5',
#        '64 + 12 + 12', '50 + 2 + 2', '48 + 2 + 2', '50 + 8 + 2 + 2',
#        '48 + 5', '48 + 50 + 2', '108 + 8 + 5 + 2', '13 + 2 + 2', '13 + 2',
#        '12', '48 + 5 + 2', '50 + 8 + 2', '64 + 8 + 2 + 2', '48 + 8 + 5',
#        '64 + 8', '48 + 5 + 2 + 2', '50 + 2', '64 + 12 + 8 + 5', '64 + 2',
#        '48 + 13 + 13', '12MP + 12MP', '64MP + 12MP + 12MP',
#        '50MP + 8MP + 2MP', '50MP + 12MP', '48MP + 8MP + 2MP + 2MP',
#        '64MP + 8MP + 2MP', '50MP + 48MP + 12MP + 8MP',
#        '50MP + 16MP + 13MP + 2MP', '108MP + 16MP + 8MP', '48MP + 13MP',
#        '12MP + 12MP + 12MP', '64MP + 13MP + 12MP', '64MP + 12MP + 8MP',
#        '13MP + 5MP', '64MP + 12MP + 8MP + 5MP', '108MP + 8MP + 5MP + 2MP',
# ...

# %%
mobile['Camera (MP)'] = mobile['Camera (MP)'].str.replace(" MP", "").str.replace(" ", "")

# %%
mobile['Camera (MP)'].unique()
# Out:
# array(['12+12+12', '108+10+10+12', '48+50+8+2', '64+8+5+2', '50+12.2',
#        '12+12', '48+8+2+2', '50+13+16+2', '50+48+12+8', '64+8+2',
#        '64+12+5+5', '50+50+13+3', '64+8+5', '64+12+12', '50+2+2',
#        '48+2+2', '50+8+2+2', '48+5', '48+50+2', '108+8+5+2', '13+2+2',
#        '13+2', '12', '48+5+2', '50+8+2', '64+8+2+2', '48+8+5', '64+8',
#        '48+5+2+2', '50+2', '64+12+8+5', '64+2', '48+13+13', '50+12',
#        '50+16+13+2', '108+16+8', '48+13', '64+13+12', '64+12+8', '13+5',
#        '108+8+2', '64+5+2+2', '64+12', '48+50+8', '50+48+48', '8+2',
#        '12+12+8', '64+13+5', '12+13', '64+8+5+5', '48+8+2', '48+2',
#        '108+12+10+10', '50+5', '48+8+5+5', '108+8+2+2', '13', '48+8+5+2',
#        '13+5+2', '8', '13+5+2+2', '13+8+5+2', '13+8+2+2', '12+2+2',
#        '13+8+2', '25+8+5', '108+12+12', '12.2+16', '50+20+12+3D',
#        '64+12+2+2', '108+13+5', '48+16+5+2', '12+7', '50+12+40+3D',
#        '50+8+16+2', '48+12+5', '48+48+8+5', '40+40+8+3D', '48+12+13',
# ...

# %%
mobile[mobile['Camera (MP)'] == "108+48+12+0.3"]
# Out:
#        Brand                Model Storage RAM Screen Size (inches)  \
# 368  Samsung  Galaxy S20 Ultra 5G     128  12                  6.9
#
#        Camera (MP)  Battery Capacity (mAh) Price ($)
# 368  108+48+12+0.3                    5000      1199

# %%
mobile['Wide'] = mobile['Camera (MP)'].str.split("+").str.get(0)
mobile['Telephoto'] = mobile['Camera (MP)'].str.split("+").str.get(1)
mobile['Ultrawide'] = mobile['Camera (MP)'].str.split("+").str.get(2)
mobile['Macro'] = mobile['Camera (MP)'].str.split("+").str.get(3)

# %%
mobile['Wide'].isnull().sum()
# Out:
# 0

# %%
mobile['Telephoto'].isnull().sum()
# Out:
# 8

# %%
mobile[mobile['Telephoto'].isnull()]
# Out:
#       Brand                Model Storage RAM Screen Size (inches) Camera (MP)  \
# 32    Apple  iPhone SE (2nd Gen)      64   3                  4.7          12
# 39    Apple            iPhone XR      64   3                  6.1          12
# 60    Apple     iPhone SE (2020)      64   3                  4.7          12
# 213  Xiaomi             Redmi 9i      64   4                 6.53          13
# 250  Realme                  C20      32   2                  6.5           8
# 277   Apple     iPhone SE (2020)      64   3                  4.7          12
# 339   Apple            iPhone XR      64   3                  6.1          12
# 359   Apple     iPhone SE (2020)     128   3                  4.7          12
#
#      Battery Capacity (mAh) Price ($) Wide Telephoto Ultrawide Macro
# 32                     1821       399   12       NaN       NaN   NaN
# 39                     2942       499   12       NaN       NaN   NaN
# ...

# %%
mobile[mobile['Ultrawide'].isnull()]
# Out:
#        Brand             Model Storage RAM Screen Size (inches) Camera (MP)  \
# 4     Google           Pixel 6     128   8                  6.4     50+12.2
# 5      Apple         iPhone 13     128   4                  6.1       12+12
# 6    Samsung    Galaxy Z Flip3     256   8                  6.7       12+12
# 13     Apple    iPhone 12 Mini      64   4                  5.4       12+12
# 21   Samsung     Galaxy A22 5G     128   4                  6.6        48+5
# ..       ...               ...     ...  ..                  ...         ...
# 350    Apple    iPhone 12 mini     256   4                  5.4       12+12
# 358    Nokia               2.4      32   2                  6.5        13+2
# 359    Apple  iPhone SE (2020)     128   3                  4.7          12
# 366    Apple         iPhone 11     128   4                  6.1       12+12
# 372    Apple         iPhone XR     128   3                  6.1       12+12
#
# ...

# %%
mobile[mobile['Macro'].isnull()]
# Out:
#         Brand              Model Storage RAM Screen Size (inches) Camera (MP)  \
# 0       Apple      iPhone 13 Pro     128   6                  6.1    12+12+12
# 4      Google            Pixel 6     128   8                  6.4     50+12.2
# 5       Apple          iPhone 13     128   4                  6.1       12+12
# 6     Samsung     Galaxy Z Flip3     256   8                  6.7       12+12
# 10    OnePlus         Nord CE 5G     128   6                 6.43      64+8+2
# ..        ...                ...     ...  ..                  ...         ...
# 373    Xiaomi            Poco M3     128   4                 6.53      48+2+2
# 375  Motorola         Moto G Pro     128   4                  6.4     48+16+2
# 376    Huawei           P30 Lite     128   4                 6.15      48+8+2
# 377   Samsung   Galaxy Note20 5G     128   8                  6.7    12+64+12
# 379     Apple  iPhone 12 Pro Max     128   6                  6.7    12+12+12
#
# ...

# %%
mobile['Telephoto'].fillna(0, inplace = True)

# %%
mobile['Telephoto'].isnull().sum()
# Out:
# 0

# %%
mobile.fillna({"Ultrawide":0, "Macro":0}, inplace = True)

# %%
mobile['Ultrawide'].isnull().sum()
# Out:
# 0

# %%
mobile['Macro'].isnull().sum()
# Out:
# 0

# %%
mobile['Macro'].unique()
# Out:
# array([0, '12', '2', '8', '5', '3', '10', '3D', 'ToF', '0.3'],
#       dtype=object)

# %%
mobile[mobile['Macro']== '0.3']
# Out:
#        Brand                Model Storage RAM Screen Size (inches)  \
# 368  Samsung  Galaxy S20 Ultra 5G     128  12                  6.9
#
#        Camera (MP)  Battery Capacity (mAh) Price ($) Wide Telephoto Ultrawide  \
# 368  108+48+12+0.3                    5000      1199  108        48        12
#
#     Macro
# 368   0.3

# %%
ind = mobile[mobile['Macro'] == '3D'].index
inde = mobile[mobile['Macro'] == 'ToF'].index

# %%
mobile.loc[ind, 'Macro'] = 0
mobile.loc[inde, 'Macro'] = 0

# %%
mobile['Macro'].unique()
# Out:
# array([0, '12', '2', '8', '5', '3', '10', '0.3'], dtype=object)

# %%
mobile
# Out:
#        Brand              Model Storage RAM Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro     128   6                  6.1
# 1    Samsung   Galaxy S21 Ultra     256  12                  6.8
# 2    OnePlus              9 Pro     128   8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro     128   6                 6.67
# 4     Google            Pixel 6     128   8                  6.4
# ..       ...                ...     ...  ..                  ...
# 376   Huawei           P30 Lite     128   4                 6.15
# 377  Samsung   Galaxy Note20 5G     128   8                  6.7
# 378   Xiaomi      Mi 10 Lite 5G     128   6                 6.57
# 379    Apple  iPhone 12 Pro Max     128   6                  6.7
# 380     Oppo              Reno3     128   8                  6.4
#
#       Camera (MP)  Battery Capacity (mAh) Price ($) Wide Telephoto Ultrawide  \
# 0        12+12+12                    3095       999   12        12        12
# ...

# %%
mobile['Screen Size (inches)'].unique()
# Out:
# array(['6.1', '6.8', '6.7', '6.67', '6.4', '6.55', '6.78', '6.43', '6.5',
#        '6.62', '5.4', '6.2', '6.51', '6.6', '4.7', '6.58', '6.52', '6.44',
#        '6.53', '6.56', '6.8 + 3.9', '4.5', '6.39', '5.9', '5.5', '6.81',
#        '5.99', '6.82', '6.3', '6.22', '6', '6.35', '6.9', '6.76', '6.49',
#        '6.72', '5.7', '6.47', '7.6 (unfolded)', '6.15', '6.57'],
#       dtype=object)

# %%
mobile[mobile['Screen Size (inches)'] == '7.6 (unfolded)']
# Out:
#        Brand              Model Storage RAM Screen Size (inches) Camera (MP)  \
# 354  Samsung  Galaxy Z Fold2 5G     256  12       7.6 (unfolded)    12+12+12
#
#      Battery Capacity (mAh) Price ($) Wide Telephoto Ultrawide Macro
# 354                    4500      1999   12        12        12     0

# %%
mobile.loc[354, 'Screen Size (inches)'] = "7.6"

# %%
mobile[mobile['Screen Size (inches)'] == '6.8 + 3.9']
# Out:
#    Brand Model Storage RAM Screen Size (inches) Camera (MP)  \
# 86    LG  Wing     256   8            6.8 + 3.9    64+13+12
#
#     Battery Capacity (mAh) Price ($) Wide Telephoto Ultrawide Macro
# 86                    4000     $999    64        13        12     0

# %%
mobile.loc[86, 'Screen Size (inches)'] = "6.8"

# %%
mobile.columns
# Out:
# Index(['Brand', 'Model', 'Storage', 'RAM', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)', 'Wide',
#        'Telephoto', 'Ultrawide', 'Macro'],
#       dtype='object')

# %%
mobile['Battery Capacity (mAh)'].unique()
# Out:
# array([3095, 5000, 4500, 5020, 4614, 2815, 3300, 5160, 2227, 4250, 4000,
#        4310, 6000, 3110, 1821, 2942, 4520, 3969, 4352, 4200, 4600, 4300,
#        4450, 4630, 3000, 3500, 4950, 5050, 4820, 7000, 4230, 4470, 4100,
#        4080, 4400, 4350, 3885, 4850, 2800, 4510, 3174, 2691, 4800, 4115,
#        3340, 4160, 3687, 4025], dtype=int64)

# %%
mobile['Price ($)'].unique()
# Out:
# array(['999', '1199', '899', '279', '799', '249', '699', '329', '449',
#        '199', '299', '379', '179', '729', '599', '139', '189', '399',
#        '259', '159', '229', '499', '129', '529', '369', '1099', '169',
#        '99', '459', '239', '1299', '429', '659', '269', '359', '$799 ',
#        '$399 ', '$699 ', '$329 ', '$999 ', '$549 ', '$1,299 ', '$899 ',
#        '$449 ', '$319 ', '$269 ', '$349 ', '$279 ', '$249 ', '$299 ',
#        '$969 ', '$1,199 ', '$149 ', '$139 ', '$99 ', '$199 ', '$169 ',
#        '$499 ', '$179 ', '$219 ', '$229 ', '$239 ', '$109 ', '$189 ',
#        '$389 ', '$309 ', '$369 ', '$129 ', '$849 ', '$469 ', '$209 ',
#        '$119 ', '$339 ', '$429 ', '$159 ', '$379 ', '$289 ', '130', '749',
#        '149', '969', '649', '349', '419', '1399', '1999', '119', '319',
#        '1049'], dtype=object)

# %%
mobile['Price ($)'] = mobile['Price ($)'].str.replace("$", "").str.replace(",", "")

# %%
mobile['Price ($)'].unique()
# Out:
# array(['999', '1199', '899', '279', '799', '249', '699', '329', '449',
#        '199', '299', '379', '179', '729', '599', '139', '189', '399',
#        '259', '159', '229', '499', '129', '529', '369', '1099', '169',
#        '99', '459', '239', '1299', '429', '659', '269', '359', '799 ',
#        '399 ', '699 ', '329 ', '999 ', '549 ', '1299 ', '899 ', '449 ',
#        '319 ', '269 ', '349 ', '279 ', '249 ', '299 ', '969 ', '1199 ',
#        '149 ', '139 ', '99 ', '199 ', '169 ', '499 ', '179 ', '219 ',
#        '229 ', '239 ', '109 ', '189 ', '389 ', '309 ', '369 ', '129 ',
#        '849 ', '469 ', '209 ', '119 ', '339 ', '429 ', '159 ', '379 ',
#        '289 ', '130', '749', '149', '969', '649', '349', '419', '1399',
#        '1999', '119', '319', '1049'], dtype=object)

# %%
mobile.drop(columns= 'Camera (MP)', inplace = True)

# %%
mobile
# Out:
#        Brand              Model Storage RAM Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro     128   6                  6.1
# 1    Samsung   Galaxy S21 Ultra     256  12                  6.8
# 2    OnePlus              9 Pro     128   8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro     128   6                 6.67
# 4     Google            Pixel 6     128   8                  6.4
# ..       ...                ...     ...  ..                  ...
# 376   Huawei           P30 Lite     128   4                 6.15
# 377  Samsung   Galaxy Note20 5G     128   8                  6.7
# 378   Xiaomi      Mi 10 Lite 5G     128   6                 6.57
# 379    Apple  iPhone 12 Pro Max     128   6                  6.7
# 380     Oppo              Reno3     128   8                  6.4
#
#      Battery Capacity (mAh) Price ($) Wide Telephoto Ultrawide Macro
# 0                      3095       999   12        12        12     0
# ...

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381 entries, 0 to 380
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   381 non-null    object
#  1   Model                   381 non-null    object
#  2   Storage                 381 non-null    object
#  3   RAM                     381 non-null    object
#  4   Screen Size (inches)    381 non-null    object
#  5   Battery Capacity (mAh)  381 non-null    int64
#  6   Price ($)               381 non-null    object
#  7   Wide                    381 non-null    object
#  8   Telephoto               381 non-null    object
#  9   Ultrawide               381 non-null    object
#  10  Macro                   381 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 43.8+ KB
