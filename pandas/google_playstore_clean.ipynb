# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
google = pd.read_csv('google_playstore_clean.csv')
google.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews  Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159   19M     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967   14M    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510  8.7M   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644   25M  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967  2.8M    100000  Free    0.0
#
#   Content Rating                     Genres Last Updated         Current Ver  \
# 0       Everyone               Art & Design   2018-01-07               1.0.0
# ...

# %%
google.duplicated().sum()
# Out:
# 0

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10357 entries, 0 to 10356
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      10357 non-null  int64
#  1   App             10357 non-null  object
#  2   Category        10357 non-null  object
#  3   Rating          10357 non-null  float64
#  4   Reviews         10357 non-null  int64
#  5   Size            10357 non-null  object
#  6   Installs        10357 non-null  int64
#  7   Type            10357 non-null  object
#  8   Price           10357 non-null  float64
#  9   Content Rating  10357 non-null  object
#  10  Genres          10357 non-null  object
#  11  Last Updated    10357 non-null  object
#  12  Current Ver     10357 non-null  object
#  13  Android Ver     10357 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 1.1+ MB

# %%
google.columns
# Out:
# Index(['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
google.drop(columns='Unnamed: 0', inplace = True)

# %%
google
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10352                                   Sya9a Maroc - FR               FAMILY
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10354                             Parkinson Exercices FR              MEDICAL
# 10355                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
google.describe()
# Out:
#              Rating       Reviews      Installs         Price
# count  10357.000000  1.035700e+04  1.035700e+04  10357.000000
# mean       3.679695  4.059046e+05  1.415776e+07      1.030800
# std        1.354984  2.696778e+06  8.023955e+07     16.278625
# min        0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        3.700000  3.200000e+01  1.000000e+03      0.000000
# 50%        4.200000  1.680000e+03  1.000000e+05      0.000000
# 75%        4.500000  4.641600e+04  1.000000e+06      0.000000
# max        5.000000  7.815831e+07  1.000000e+09    400.000000

# %%
# App
google['App'].value_counts()
# Out:
# App
# ROBLOX                                           9
# 8 Ball Pool                                      7
# Bubble Shooter                                   6
# Helix Jump                                       6
# Zombie Catchers                                  6
#                                                 ..
# Popsicle Launcher for Android P 9.0 launcher     1
# PixelLab - Text on pictures                      1
# P Launcher for Android™ 9.0                      1
# Pacify (Android P theme) - Theme for Xperia™     1
# iHoroscope - 2018 Daily Horoscope & Astrology    1
# Name: count, Length: 9659, dtype: int64

# %%
print("Helllo Worldsdssssssss")
# Out:
# Helllo Worldsdssssssss

# %%
google.groupby('Category')['Rating'].max().reset_index()
# Out:
#                Category  Rating
# 0        ART_AND_DESIGN     5.0
# 1     AUTO_AND_VEHICLES     4.9
# 2                BEAUTY     4.9
# 3   BOOKS_AND_REFERENCE     5.0
# 4              BUSINESS     5.0
# 5                COMICS     5.0
# 6         COMMUNICATION     5.0
# 7                DATING     5.0
# 8             EDUCATION     4.9
# 9         ENTERTAINMENT     4.7
# 10               EVENTS     5.0
# 11               FAMILY     5.0
# 12              FINANCE     5.0
# 13       FOOD_AND_DRINK     5.0
# 14                 GAME     5.0
# 15   HEALTH_AND_FITNESS     5.0
# 16       HOUSE_AND_HOME     4.8
# 17   LIBRARIES_AND_DEMO     5.0
# 18            LIFESTYLE     5.0
# 19  MAPS_AND_NAVIGATION     4.9
# 20              MEDICAL     5.0
# 21   NEWS_AND_MAGAZINES     5.0
# 22            PARENTING     5.0
# 23      PERSONALIZATION     5.0
# 24          PHOTOGRAPHY     5.0
# 25         PRODUCTIVITY     5.0
# 26             SHOPPING     5.0
# 27               SOCIAL     5.0
# ...

# %%
google.pivot_table(index = ['Category'], columns = 'Rating', aggfunc = 'max')
# Out:
#                             Android Ver                                  \
# Rating                              0.0                 1.0         1.2
# Category
# ART_AND_DESIGN               4.2 and up          4.1 and up         NaN
# AUTO_AND_VEHICLES            6.0 and up         4.4W and up         NaN
# BEAUTY                       4.1 and up          5.0 and up         NaN
# BOOKS_AND_REFERENCE          4.4 and up          6.0 and up         NaN
# BUSINESS             Varies with device  Varies with device         NaN
# COMICS                              NaN          4.4 and up         NaN
# COMMUNICATION        Varies with device  Varies with device         NaN
# DATING                       4.4 and up          4.4 and up         NaN
# EDUCATION                           NaN          4.0 and up         NaN
# ENTERTAINMENT                       NaN                 NaN         NaN
# EVENTS                       4.4 and up         4.4W and up         NaN
# ...

# %%
google.loc[google.groupby('Category')['Rating'].idxmax()][['App', 'Category', 'Rating']]
# Out:
#                                                     App             Category  \
# 8407            Spring flowers theme couleurs d t space       ART_AND_DESIGN
# 55    Tickets SDA 2018 and Exam from the State Traff...    AUTO_AND_VEHICLES
# 99                       ipsy: Makeup, Beauty, and Tips               BEAUTY
# 4084                      R Programing Offline Tutorial  BOOKS_AND_REFERENCE
# 4670                              Ag Valley Cooperative             BUSINESS
# 296                        Hojiboy Tojiboyev Life Hacks               COMICS
# 6261                                          BS-Mobile        COMMUNICATION
# 546                       American Girls Mobile Numbers               DATING
# 628      Learn Japanese, Korean, Chinese Offline & Free            EDUCATION
# 772    🔥 Football Wallpapers 4K | Full HD Backgrounds 😍        ENTERTAINMENT
# 880                                    SUMMER SONIC app               EVENTS
# ...

# %%
# if an app is paid, then calculate the total revenue for each category.
paid_apps = google[google['Type'] == 'Paid']
google['Revenue'] =  google['Price'] * google['Installs']
# paid_apps
paid_apps.groupby('Category')['Revenue'].sum()
# Out:
# Category
# ART_AND_DESIGN         3.184000e+04
# AUTO_AND_VEHICLES      1.001485e+05
# BOOKS_AND_REFERENCE    9.022674e+04
# BUSINESS               1.050543e+06
# COMMUNICATION          4.247364e+06
# DATING                 8.836150e+04
# EDUCATION              2.403980e+06
# ENTERTAINMENT          7.980000e+05
# EVENTS                 1.099900e+02
# FAMILY                 1.857803e+08
# FINANCE                2.572668e+07
# FOOD_AND_DRINK         2.844000e+05
# GAME                   4.098764e+07
# HEALTH_AND_FITNESS     1.426069e+06
# LIBRARIES_AND_DEMO     9.900000e+01
# LIFESTYLE              5.758394e+07
# MAPS_AND_NAVIGATION    1.240789e+06
# MEDICAL                8.456536e+06
# NEWS_AND_MAGAZINES     6.445000e+03
# PARENTING              2.499590e+05
# PERSONALIZATION        7.786948e+06
# PHOTOGRAPHY            8.942768e+06
# PRODUCTIVITY           4.313375e+06
# SHOPPING               3.014900e+04
# SOCIAL                 5.940000e+03
# SPORTS                 4.706212e+06
# ...

# %%
google[google['Category'] == "ART_AND_DESIGN"]
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 6705                            Easy DIY CD Craft Ideas  ART_AND_DESIGN
# 8198                                       Dp for girls  ART_AND_DESIGN
# 8231             Name Art DP - Focus n Filter Text 2018  ART_AND_DESIGN
# 8390                             Test Application DT 02  ART_AND_DESIGN
# 8407            Spring flowers theme couleurs d t space  ART_AND_DESIGN
#
#       Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
google
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10352                                   Sya9a Maroc - FR               FAMILY
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10354                             Parkinson Exercices FR              MEDICAL
# 10355                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
google[google['Last Updated'].str.split('-').str.get(1) == '01'] # app last updated on january only
# Out:
#                                                   App             Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                 Coloring book moana       ART_AND_DESIGN
# 33                                 Easy Origami Ideas       ART_AND_DESIGN
# 44        Popsicle Sticks and Similar DIY Craft Ideas       ART_AND_DESIGN
# 134                     Lady adviser (beauty, health)               BEAUTY
# ...                                               ...                  ...
# 10310                                         PopStar               FAMILY
# 10317                             Fr Ignacio Outreach               FAMILY
# 10346                               News Minecraft.fr   NEWS_AND_MAGAZINES
# 10354                          Parkinson Exercices FR              MEDICAL
# 10355                   The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# ...

# %%
google[google['Last Updated'].str.split('-').str.get(0) == '2018'] # apps last updated in 2018 only
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10342          Frim: get new friends on local chat rooms               SOCIAL
# 10343                                 Fr Agnel Ambarnath               FAMILY
# 10347                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
google['Last Updated'].str.split('-').str.get(0).value_counts()
# Out:
# Last Updated
# 2018    6934
# 2017    1826
# 2016     789
# 2015     454
# 2014     204
# 2013     108
# 2012      26
# 2011      15
# 2010       1
# Name: count, dtype: int64

# %%
sns.countplot(x = google['Last Updated'].str.split('-').str.get(0))
# Out:
# <Axes: xlabel='Last Updated', ylabel='count'>

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10357 entries, 0 to 10356
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          10357 non-null  float64
#  3   Reviews         10357 non-null  int64
#  4   Size            10357 non-null  object
#  5   Installs        10357 non-null  int64
#  6   Type            10357 non-null  object
#  7   Price           10357 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10357 non-null  object
#  12  Android Ver     10357 non-null  object
#  13  Revenue         10357 non-null  float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
google['Last Updated'] = pd.to_datetime(google['Last Updated'])

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10357 entries, 0 to 10356
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          10357 non-null  float64
#  3   Reviews         10357 non-null  int64
#  4   Size            10357 non-null  object
#  5   Installs        10357 non-null  int64
#  6   Type            10357 non-null  object
#  7   Price           10357 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  datetime64[ns]
#  11  Current Ver     10357 non-null  object
#  12  Android Ver     10357 non-null  object
#  13  Revenue         10357 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
google['Year'] = google['Last Updated'].dt.year

# %%
google['Month'] = google['Last Updated'].dt.month

# %%
google['Da'] = google['Last Updated'].dt.day

# %%
google
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10352                                   Sya9a Maroc - FR               FAMILY
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10354                             Parkinson Exercices FR              MEDICAL
# 10355                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
google['WDays'] = google['Last Updated'].dt.day_name()

# %%
google
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10352                                   Sya9a Maroc - FR               FAMILY
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10354                             Parkinson Exercices FR              MEDICAL
# 10355                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
google['Month'] = google['Last Updated'].dt.month_name()

# %%
google
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10352                                   Sya9a Maroc - FR               FAMILY
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10354                             Parkinson Exercices FR              MEDICAL
# 10355                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...
