# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ecom_purch = pd.read_csv('Ecommerce Purchases')
ecom_purch
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom_purch.sample()
# Out:
#                                                Address    Lot AM or PM  \
# 8444  8153 Roman Gateway\nLake Elizabethbury, AR 15874  64 Tw       AM
#
#                                            Browser Info          Company  \
# 8444  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...  Gonzalez-Baxter
#
#            Credit Card CC Exp Date  CC Security Code   CC Provider  \
# 8444  6011896651973377       06/25               880  JCB 16 digit
#
#                  Email         Job   IP Address Language  Purchase Price
# 8444  hdixon@yahoo.com  Oncologist  79.79.15.17       zh           56.15

# %%
ecom_purch.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
ecom_purch.sample(20)
# Out:
#                                                 Address    Lot AM or PM  \
# 1335  108 Browning Point\nEast Briantown, GU 09303-4401  22 kE       PM
# 2507   273 Fields Islands Apt. 813\nRobinfurt, OH 87555  00 as       PM
# 9102          749 Brooks Alley\nKevinton, DC 71649-9770  92 wf       PM
# 6016  019 Scott Landing\nLake Brandontown, MP 01574-...  99 GE       AM
# 2829  30252 Michele Manors Suite 700\nNorth Thomasfo...  60 yq       AM
# 7293          37218 Margaret Path\nLindahaven, PA 04944  68 Es       PM
# 4200      779 Burns Bypass\nNew Michelle, NM 32283-5951  28 vI       AM
# 4285  2228 Thomas Knolls Suite 018\nSouth Karen, NY ...  61 rL       AM
# 8813    955 Tammy Terrace Apt. 049\nScottberg, IA 92797  47 DI       AM
# 2623  505 Scott Meadow\nSouth Meredithland, IN 57192...  58 ej       PM
# 3425      055 Jonathan View\nSuzanneside, MO 52171-9758  95 ud       PM
# 8168       623 Anderson Throughway\nNew Wendy, NV 70277  62 xA       PM
# ...

# %%
ecom_purch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
ecom_purch.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %% [markdown]
# ecom_purch.isnull().sum()

# %%
ecom_purch.duplicated().sum()
# Out:
# 0

# %%
ecom_purch.shape
# Out:
# (10000, 14)

# %%
ecom_purch.columns.nunique()
# Out:
# 14

# %%
ecom_purch[ecom_purch[['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
       'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
       'IP Address', 'Language', 'Purchase Price']].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Address, Lot, AM or PM, Browser Info, Company, Credit Card, CC Exp Date, CC Security Code, CC Provider, Email, Job, IP Address, Language, Purchase Price]
# Index: []

# %% [markdown]
# # ecom_purch dataframe:
# - 10000 rows and 14 columns.
# - No any null values in the dataset.
# - CC & Security Code - Int64
# - Purchase Price - Float64
# - Other columns - Object
# - Total Counts : 10000
# - Purchase Price Minimum: 0.000000
# - Purchase Price Maximum: 99.990000
# - Purchase Price Average/Mean: 50.347302
# - No Duplicate entries

# %%
ecom_purch[ecom_purch['CC Security Code'] == 0]
# Out:
#                                                 Address    Lot AM or PM  \
# 2878          212 Mcgee Motorway\nRhodesmouth, NE 11657  55 qJ       AM
# 3657    9153 Barron Brook Apt. 446\nSmithtown, DE 98468  49 gT       AM
# 5273  87666 Ryan Corners\nWest Angelaborough, NC 042...  06 lo       PM
# 5400  90517 Sweeney Crest Apt. 996\nSouth Amy, HI 96...  82 tH       PM
# 8877              PSC 6610, Box 2871\nAPO AE 39171-6454  80 Kd       AM
# 8940       961 Jessica Harbor\nKevinfort, IL 28482-5760  07 nl       AM
# 8959             56425 Lindsey Club\nBrianton, AZ 19952  42 FI       PM
# 9207      052 Robin Track Apt. 852\nBatesport, VI 40100  99 BF       AM
#
#                                            Browser Info  \
# 2878  Opera/8.55.(Windows NT 5.01; en-US) Presto/2.9...
# 3657  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# 5273  Mozilla/5.0 (Windows NT 4.0; it-IT; rv:1.9.1.2...
# 5400  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5;...
# ...

# %%
ecom_purch[ecom_purch['Purchase Price'] == 0]
# Out:
#                                                 Address    Lot AM or PM  \
# 2876  332 Jones Parkways\nEast Katherineville, GA 64230  39 GT       AM
# 5487     465 Mallory Ways\nNorth Rebecca, RI 82734-1160  93 OH       PM
#
#                                            Browser Info  \
# 2876  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_6_9...
# 5487  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 2876  Lyons, Diaz and Clark  4204500444841766       01/18                38
# 5487         Flynn and Sons    30469912089738       09/23               236
#
#         CC Provider                 Email                   Job  \
# 2876  VISA 16 digit  jennifer11@baker.com  Biomedical scientist
# 5487       Discover   mjohnson@austin.org         Stage manager
#
#           IP Address Language  Purchase Price
# 2876  223.47.177.174       it             0.0
# 5487     43.99.56.59       zh             0.0

# %% [markdown]
# # Univariate Analysis

# %%
ecom_purch['Address'].isnull().sum()
# Out:
# 0

# %%
ecom_purch['Address'].nunique()
# Out:
# 10000

# %%
ecom_purch['Lot'].nunique()
# Out:
# 9822

# %%
ecom_purch[ecom_purch['Lot'].duplicated(keep = False)].sort_values(by = 'Lot')
# Out:
#                                                 Address    Lot AM or PM  \
# 5834  8424 Martinez Viaduct Apt. 273\nBrighthaven, O...  00 dP       AM
# 7632           54826 Bradley Loaf\nJeremybury, WV 68567  00 dP       PM
# 948   84580 Courtney Roads Apt. 301\nPort Steven, NE...  00 ub       PM
# 8150        136 Amber Courts\nWest Alyssaberg, MI 23995  00 ub       AM
# 8972  577 Golden Streets Apt. 920\nMcdonaldport, ME ...  01 Ca       PM
# ...                                                 ...    ...      ...
# 9345  786 Sarah Drives Apt. 147\nLake Lisahaven, NE ...  98 QN       PM
# 4797  4733 Luna Ranch\nEast Kimberlyview, AZ 98469-5426  98 TP       PM
# 570   3669 Stacy Inlet Suite 647\nPort Adrienne, MT ...  98 TP       PM
# 8538  561 Rodriguez Divide Apt. 920\nNorth Davidshir...  98 sI       PM
# 1255  8508 Delacruz Motorway Apt. 422\nSouth Jessepo...  98 sI       AM
#
#                                            Browser Info  \
# ...

# %%
# 9822/10000 unique Lots

# %%
ecom_purch['AM or PM'].nunique()
# Out:
# 2

# %%
ecom_purch['AM or PM'].isnull().sum()
# Out:
# 0

# %%
ecom_purch['AM or PM'].value_counts().plot(kind='pie', autopct = "%0.0f%%" )
# Out:
# <Axes: ylabel='count'>

# %%
ax = sns.countplot(x=ecom_purch['AM or PM'])
for container in ax.containers:
    ax.bar_label(container, fmt = '%.0f', label_type = 'edge', padding = 3)
    print(container)
plt.show()
# Out:
# <BarContainer object of 2 artists>

# %%
# number of sales at PM(51%) > no. of sales at AM(49%). 
ecom_purch['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
# broswer
ecom_purch['Browser Info'].nunique()
# Out:
# 8287

# %%
ecom_purch['Browser Info'].duplicated().sum()
# Out:
# 1713

# %%
ecom_purch[ecom_purch['Browser Info'].duplicated(keep = False)].sort_values(by = 'Browser Info')
# Out:
#                                                 Address    Lot AM or PM  \
# 7535   8161 Jacobs Mountain\nWest Chelseatown, AZ 01314  72 Il       AM
# 2230     82222 Anderson Run\nMorenohaven, MI 17420-9988  30 ry       AM
# 8350              PSC 2815, Box 1596\nAPO AE 30287-5140  98 Hz       AM
# 5598  72255 Carl Causeway Suite 268\nCameronmouth, V...  18 Af       PM
# 2707  09541 Anderson Shore\nClaudiaburgh, LA 42859-3341  56 dj       PM
# ...                                                 ...    ...      ...
# 391   89678 Lewis Crossing\nEast Scotttown, ND 70920...  30 ft       AM
# 8336              PSC 4596, Box 2815\nAPO AP 33546-3616  19 fw       PM
# 205   43656 Wiggins Ranch Suite 839\nSouth Susan, OK...  89 nV       PM
# 8468    70723 Lopez Parks Suite 066\nWolfeton, AK 70008  47 SB       PM
# 1004     1082 Jason Stream\nBradfordview, AS 52241-0199  86 sO       AM
#
#                                            Browser Info  \
# ...

# %%
# 1713 duplicated broswer info

# %%
# company
ecom_purch['Company'].nunique()
# Out:
# 8653

# %%
ecom_purch['Company'].duplicated().sum()
# Out:
# 1347

# %%
# 8653 unique companies. 
# 1347 duplicated companies.

# %%
# credit card
ecom_purch['Credit Card'].nunique()
# Out:
# 10000

# %%
ecom_purch['CC Exp Date'].isnull().sum()
# Out:
# 0

# %%
ecom_purch['CC Exp Date'].nunique()
# Out:
# 121

# %%
ecom_purch['CC Security Code'].nunique()
# Out:
# 1758

# %%
# 1758 unique security codes.

# %%
# email
ecom_purch['Email'].nunique()
# Out:
# 9954

# %%
ecom_purch['Email'].duplicated().value_counts()
# Out:
# Email
# False    9954
# True       46
# Name: count, dtype: int64

# %%
ecom_purch[ecom_purch['Email'].duplicated(keep= False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 91            874 Tanner Islands\nJosephhaven, ND 47343  64 Aj       AM
# 223   7965 Gardner Trail\nWest Robertport, MT 38876-...  15 Ee       AM
# 431    728 Lori Via Apt. 120\nDarylshire, HI 75881-1046  93 nZ       AM
# 433       9667 Michael Road\nSouth Tylershire, UT 36934  10 Mo       AM
# ...                                                 ...    ...      ...
# 9174                   Unit 6545 Box 2090\nDPO AA 05290  65 RJ       PM
# 9267  9277 Caldwell Ville Apt. 884\nGabrielhaven, AL...  76 kq       PM
# 9456    2372 Brian Summit\nNew Stephaniehaven, GA 66547  67 zZ       PM
# 9520  743 Hatfield Port Apt. 784\nPort Claytonville,...  27 UU       AM
# 9678            319 Kyle Causeway\nWest Stacy, MO 47877  34 QI       AM
#
#                                            Browser Info  \
# ...

# %%
# 46 duplicated emails found.

# %%
ecom_purch['CC Provider'].nunique()
# Out:
# 10

# %%
ecom_purch['CC Provider'].value_counts()
# Out:
# CC Provider
# JCB 16 digit                   1716
# VISA 16 digit                  1715
# JCB 15 digit                    868
# American Express                849
# Maestro                         846
# Voyager                         829
# Discover                        817
# Mastercard                      816
# VISA 13 digit                   777
# Diners Club / Carte Blanche     767
# Name: count, dtype: int64

# %%
plt.figure(figsize = (15, 5))
sns.countplot(y=ecom_purch['CC Provider'])
# plt.xticks(rotation = 20)
plt.show()

# %%
# JCB 16 digit and Visa 16 digit are the mostly used cc service providers.
# Diners Club / Carte Blanche is the least used cc service provider.

# %%
ecom_purch['Email'].value_counts()>1
# Out:
# Email
# leekathy@yahoo.com            True
# joshua41@hotmail.com          True
# christopher29@gmail.com       True
# ethomas@hotmail.com           True
# brownjohn@hotmail.com         True
#                              ...
# jamesbarnett@gomez.org       False
# hernandezrobert@frank.com    False
# lindseywilliams@pratt.com    False
# ann28@hotmail.com            False
# rachelford@vaughn.com        False
# Name: count, Length: 9954, dtype: bool

# %%
ecom_purch[ecom_purch['Email'].duplicated(keep = False)].sort_values(by='Email')
# Out:
#                                                 Address    Lot AM or PM  \
# 7925           3856 Jessica Corner\nBrianview, OH 30437  22 rd       PM
# 433       9667 Michael Road\nSouth Tylershire, UT 36934  10 Mo       AM
# 3679  221 Kane Branch Apt. 484\nMelissamouth, NE 613...  40 vk       PM
# 8561                   PSC 5060, Box 5337\nAPO AA 78010  36 IN       AM
# 5300  63914 Valdez Street Suite 470\nNorth Brittanym...  15 JC       AM
# ...                                                 ...    ...      ...
# 3119   6719 Brown Cove\nSouth Teresatown, VI 96146-5186  20 Uo       PM
# 6694  38516 Kemp Knoll Suite 387\nWangstad, VA 35691...  65 Fu       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 1913                      USNS Ellis\nFPO AA 84124-1746  13 Tk       PM
# 2585  2626 Stokes Union Suite 410\nNorth Larryhaven,...  89 sV       PM
#
#                                            Browser Info  \
# ...

# %%
ecom_purch['Job'].nunique()
# Out:
# 623

# %%
ecom_purch[ecom_purch['Job'].str.contains('Engineer', case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
ecom_purch['IP Address'].nunique()
# Out:
# 10000

# %%
# language
ecom_purch['Language'].nunique()
# Out:
# 9

# %%
ecom_purch['Language'].value_counts()
# Out:
# Language
# de    1155
# ru    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: count, dtype: int64

# %%
# de and ru mostly spoken languages.
# zh is least spoken language.

# %%
ecom_purch['Language'].value_counts().plot(kind='pie',autopct = "%0.0f%%" )
# Out:
# <Axes: ylabel='count'>

# %%
ax = sns.countplot(x=ecom_purch['Language'])
for container in ax.containers:
    ax.bar_label(container, fmt = '%.0f', label_type = 'edge', padding = 3)
    # print(container)
plt.show()

# %%
french_speakers = ecom_purch['Language'].value_counts()['fr']
print("French speakers: ", french_speakers)
# Out:
# French speakers:  1097

# %%
ecom_purch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
ecom_purch['Purchase Price'].nunique()
# Out:
# 6349

# %%
ecom_purch['Purchase Price'].describe(include='all')
# Out:
# count    10000.000000
# mean        50.347302
# std         29.015836
# min          0.000000
# 25%         25.150000
# 50%         50.505000
# 75%         75.770000
# max         99.990000
# Name: Purchase Price, dtype: float64

# %%
sns.boxplot(x = ecom_purch['Purchase Price'])
# Out:
# <Axes: xlabel='Purchase Price'>

# %%
ecom_purch['Purchase Price'].skew()
# Out:
# -0.008915427812629589

# %%
sns.histplot(data=ecom_purch, x="Purchase Price", bins = 10 )
# Out:
# <Axes: xlabel='Purchase Price', ylabel='Count'>

# %%
sns.kdeplot(x=ecom_purch['Purchase Price'])
# Out:
# <Axes: xlabel='Purchase Price', ylabel='Density'>

# %%
# with fig lekhera aaune value sahit

# %%
ecom_purch[ecom_purch['Purchase Price'] == 0]
# Out:
#                                                 Address    Lot AM or PM  \
# 2876  332 Jones Parkways\nEast Katherineville, GA 64230  39 GT       AM
# 5487     465 Mallory Ways\nNorth Rebecca, RI 82734-1160  93 OH       PM
#
#                                            Browser Info  \
# 2876  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_6_9...
# 5487  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 2876  Lyons, Diaz and Clark  4204500444841766       01/18                38
# 5487         Flynn and Sons    30469912089738       09/23               236
#
#         CC Provider                 Email                   Job  \
# 2876  VISA 16 digit  jennifer11@baker.com  Biomedical scientist
# 5487       Discover   mjohnson@austin.org         Stage manager
#
#           IP Address Language  Purchase Price
# 2876  223.47.177.174       it             0.0
# 5487     43.99.56.59       zh             0.0

# %%
# find email of the person with ip add: 132.207.160.22
ecom_purch[ecom_purch['IP Address'] == '132.207.160.22'][['Email', 'IP Address']]
# Out:
#                             Email      IP Address
# 2  amymiller@morales-harrison.com  132.207.160.22

# %%
ecom_purch['CC Provider'].value_counts()
# Out:
# CC Provider
# JCB 16 digit                   1716
# VISA 16 digit                  1715
# JCB 15 digit                    868
# American Express                849
# Maestro                         846
# Voyager                         829
# Discover                        817
# Mastercard                      816
# VISA 13 digit                   777
# Diners Club / Carte Blanche     767
# Name: count, dtype: int64

# %%
ecom_purch[(ecom_purch['CC Provider'].str.contains('Mastercard', case = False)) & (ecom_purch['Purchase Price']>50) ]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
ecom_purch[(ecom_purch['CC Provider'].str.contains('Mastercard', case = False)) & (ecom_purch['Purchase Price']>50) ].shape[0]
# Out:
# 405

# %%
len(ecom_purch[(ecom_purch['CC Provider'].str.contains('Mastercard', case = False)) & (ecom_purch['Purchase Price']>50) ])
# Out:
# 405

# %%
# email of the person with cc num:  4690863684605
ecom_purch[ecom_purch['Credit Card'] == 4690863684605]['Email']
# Out:
# 9981    laurenbennett@richards.com
# Name: Email, dtype: object

# %%
# person purchase during AM and PM
am_sales = ecom_purch['AM or PM'].value_counts()['AM']
pm_sales = ecom_purch['AM or PM'].value_counts()['PM']
print(f"No of persons purchase during AM: {am_sales}")
print(f"No of persons purchase during PM: {pm_sales}")
# Out:
# No of persons purchase during AM: 4932
# No of persons purchase during PM: 5068

# %%
# no of people with cc expired in 2020
ecom_purch[ecom_purch['CC Exp Date'].str.split("/").str.get(1) == '20' ].shape[0]
# Out:
# 988

# %%
# top 5 most popular email provider
ecom_purch['Email'].str.split('@').str.get(1).value_counts()[:5]
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
# famous web browser
ecom_purch['Browser Info'].str.split('/').str.get(0).value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Browser Info'>

# %%
provider_mean_purchase = ecom_purch.groupby('CC Provider')[['Purchase Price']].mean()
provider_mean_purchase
# Out:
#                              Purchase Price
# CC Provider
# American Express                  50.489423
# Diners Club / Carte Blanche       48.733233
# Discover                          51.662338
# JCB 15 digit                      51.125115
# JCB 16 digit                      49.299143
# Maestro                           50.379173
# Mastercard                        50.043015
# VISA 13 digit                     51.449858
# VISA 16 digit                     49.871055
# Voyager                           51.973185

# %%
plt.figure(figsize = (15,6))
ax = sns.barplot(ecom_purch, x = 'CC Provider', y = 'Purchase Price')
for container in ax.containers:
    ax.bar_label(container, fmt = '%.0f', label_type = 'edge', padding = 12)
plt.xticks(rotation = 70)
plt.show()

# %%
provider_total_purchase = ecom_purch.groupby('CC Provider')[['Purchase Price']].sum()
provider_total_purchase
# provider_total_purchase = ecom_purch.groupby('CC Provider')[['Purchase Price']].sum().reset_index()
# provider_total_purchase
# Out:
#                              Purchase Price
# CC Provider
# American Express                   42865.52
# Diners Club / Carte Blanche        37378.39
# Discover                           42208.13
# JCB 15 digit                       44376.60
# JCB 16 digit                       84597.33
# Maestro                            42620.78
# Mastercard                         40835.10
# VISA 13 digit                      39976.54
# VISA 16 digit                      85528.86
# Voyager                            43085.77

# %%
plt.figure(figsize = (15,6))
ax = sns.barplot(provider_total_purchase, x = provider_total_purchase.index, y = 'Purchase Price')
for container in ax.containers:
    ax.bar_label(container, fmt = '%.0f', label_type = 'edge', padding = 12)
plt.xticks(rotation = 70)
plt.show()

# %%
# total revenue generate either during AM or PM
ecom_purch.groupby('AM or PM')[['Purchase Price']].mean()
# Out:
#           Purchase Price
# AM or PM
# AM             50.186511
# PM             50.503779

# %%
ecom_purch.groupby('AM or PM')[['Purchase Price']].sum()
# Out:
#           Purchase Price
# AM or PM
# AM             247519.87
# PM             255953.15

# %%
ecom_purch['CC Provider']
# Out:
# 0                      JCB 16 digit
# 1                        Mastercard
# 2                      JCB 16 digit
# 3                          Discover
# 4       Diners Club / Carte Blanche
#                    ...
# 9995                   JCB 15 digit
# 9996                   JCB 16 digit
# 9997                  VISA 16 digit
# 9998               American Express
# 9999                   JCB 15 digit
# Name: CC Provider, Length: 10000, dtype: object

# %%
ecom_purch[(ecom_purch['CC Provider']=='JCB 16 digit') & (ecom_purch['CC Exp Date'].str.split('/').str.get(1)=='24')]['Purchase Price'].sum()
# Out:
# 8987.74

# %%
# cc provider wise, am or pm, and count.
ecom_purch.groupby('CC Provider')[['AM or PM']].value_counts()
# Out:
# CC Provider                  AM or PM
# American Express             AM          428
#                              PM          421
# Diners Club / Carte Blanche  PM          385
#                              AM          382
# Discover                     PM          428
#                              AM          389
# JCB 15 digit                 PM          449
#                              AM          419
# JCB 16 digit                 AM          871
#                              PM          845
# Maestro                      PM          454
#                              AM          392
# Mastercard                   PM          438
#                              AM          378
# VISA 13 digit                AM          395
#                              PM          382
# VISA 16 digit                PM          865
#                              AM          850
# Voyager                      AM          428
#                              PM          401
# ...
