# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
google_playstore = pd.read_csv('googleplaystore.csv.xls')
google_playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
google_playstore.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
google_playstore.columns.nunique()
# Out:
# 13

# %%
google_playstore.shape
# Out:
# (10841, 13)

# %%
google_playstore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
google_playstore.sample(10)
# Out:
#                                                   App             Category  \
# 9496                                       Master E.K               FAMILY
# 1641   Zoopla Property Search UK - Home to buy & rent            LIFESTYLE
# 8691             Profile Pictures and DP for Whatsapp               SOCIAL
# 4525                                Big Q Car Service  MAPS_AND_NAVIGATION
# 1114                                     Credit Karma              FINANCE
# 980                                               MTV        ENTERTAINMENT
# 10297                                   Story Time FD               FAMILY
# 1747                       Farm Fruit Pop: Party Time                 GAME
# 6343                                        Blackjack                 GAME
# 10321                                      FE Connect                TOOLS
#
#        Rating Reviews                Size     Installs  Type Price  \
# 9496      5.0      90  Varies with device       1,000+  Free     0
# 1641      4.1   21195  Varies with device   1,000,000+  Free     0
# 8691      4.3      48                 11M       5,000+  Free     0
# 4525      4.4      75                 26M       5,000+  Free     0
# 1114      4.7  706302  Varies with device  10,000,000+  Free     0
# 980       3.8   35279                 15M   1,000,000+  Free     0
# 10297     5.0       2                4.2M          10+  Free     0
# 1747      4.4    9305                 14M   1,000,000+  Free     0
# 6343      4.3   52199  Varies with device   1,000,000+  Free     0
# 10321     4.8      24                4.5M       5,000+  Free     0
#
#       Content Rating             Genres        Last Updated  \
# 9496        Everyone          Education     August 11, 2017
# 1641        Everyone          Lifestyle       June 22, 2018
# 8691        Everyone             Social        May 12, 2017
# 4525        Everyone  Maps & Navigation        May 15, 2017
# 1114        Everyone            Finance       July 31, 2018
# 980             Teen      Entertainment        July 8, 2018
# 10297   Everyone 10+         Simulation      March 25, 2016
# 1747        Everyone             Casual      August 2, 2018
# 6343            Teen             Casino        May 18, 2017
# 10321       Everyone              Tools  September 14, 2017
#
#               Current Ver         Android Ver
# 9496                1.5.0          4.4 and up
# 1641   Varies with device  Varies with device
# 8691                  1.3        4.0.3 and up
# 4525                3.002        4.0.3 and up
# 1114   Varies with device  Varies with device
# 980               11.45.0          4.4 and up
# 10297                 1.1          1.6 and up
# 1747                1.9.2        4.0.3 and up
# 6343             1.2.4.69          2.3 and up
# 10321               2.3.0        4.0.3 and up

# %%
google_playstore.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
google_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
google_playstore.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
google_playstore.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
google_playstore.duplicated().sum()
# Out:
# 483

# %%
google_playstore[google_playstore[['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
       'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
       'Android Ver']].duplicated(keep = False)].sort_values(by= 'App')
# Out:
#                                                     App            Category  \
# 1393                              10 Best Foods for You  HEALTH_AND_FITNESS
# 1407                              10 Best Foods for You  HEALTH_AND_FITNESS
# 2543                         1800 Contacts - Lens Store             MEDICAL
# 2322                         1800 Contacts - Lens Store             MEDICAL
# 2256                         2017 EMRA Antibiotic Guide             MEDICAL
# ...                                                 ...                 ...
# 3063  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3055  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3103                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 3202                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 3118                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
#
#       Rating Reviews                Size     Installs  Type   Price  \
# 1393     4.0    2490                3.8M     500,000+  Free       0
# 1407     4.0    2490                3.8M     500,000+  Free       0
# 2543     4.7   23160                 26M   1,000,000+  Free       0
# 2322     4.7   23160                 26M   1,000,000+  Free       0
# 2256     4.4      12                3.8M       1,000+  Paid  $16.99
# ...      ...     ...                 ...          ...   ...     ...
# 3063     4.4  133833                 34M  10,000,000+  Free       0
# 3055     4.4  133833                 34M  10,000,000+  Free       0
# 3103     4.2  219848  Varies with device  50,000,000+  Free       0
# 3202     4.2  219848  Varies with device  50,000,000+  Free       0
# 3118     4.2  219848  Varies with device  50,000,000+  Free       0
#
#      Content Rating            Genres       Last Updated         Current Ver  \
# 1393   Everyone 10+  Health & Fitness  February 17, 2017                 1.9
# 1407   Everyone 10+  Health & Fitness  February 17, 2017                 1.9
# 2543       Everyone           Medical      July 27, 2018               7.4.1
# 2322       Everyone           Medical      July 27, 2018               7.4.1
# 2256       Everyone           Medical   January 27, 2017               1.0.5
# ...             ...               ...                ...                 ...
# 3063   Everyone 10+            Sports      July 25, 2018              6.17.2
# 3055   Everyone 10+            Sports      July 25, 2018              6.17.2
# 3103       Everyone    Travel & Local     August 2, 2018  Varies with device
# 3202       Everyone    Travel & Local     August 2, 2018  Varies with device
# 3118       Everyone    Travel & Local     August 2, 2018  Varies with device
#
#              Android Ver
# 1393        2.3.3 and up
# 1407        2.3.3 and up
# 2543          5.0 and up
# 2322          5.0 and up
# 2256        4.0.3 and up
# ...                  ...
# 3063          4.4 and up
# 3055          4.4 and up
# 3103  Varies with device
# 3202  Varies with device
# 3118  Varies with device
#
# [893 rows x 13 columns]

# %%
# App
google_playstore['App'].isnull().sum()
# Out:
# 0

# %%
google_playstore['App'].nunique()
# Out:
# 9660

# %%
# Category
google_playstore['Category'].nunique()
# Out:
# 34

# %%
google_playstore['Category'].isnull().sum()
# Out:
# 0

# %%
google_playstore['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
# Rating
google_playstore['Rating'].isnull().sum()
# Out:
# 1474

# %%
google_playstore['Rating'].describe()
# Out:
# count    9367.000000
# mean        4.193338
# std         0.537431
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64

# %%
google_playstore[google_playstore['Rating'] == 19.000000]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
google_playstore[google_playstore['Rating'] > 5.000000]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
google_playstore.drop(10472, inplace = True)

# %%
google_playstore[google_playstore['Rating'].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# 23         61  7.0M  100,000+  Free     0       Everyone
# 113       182  5.7M  100,000+  Free     0   Everyone 10+
# 123       119  3.7M   50,000+  Free     0       Everyone
# 126       654  7.4M  100,000+  Free     0           Teen
# 129        77  2.9M   10,000+  Free     0     Mature 17+
# ...       ...   ...       ...   ...   ...            ...
# 10824      67   82M   10,000+  Free     0       Everyone
# 10825       7  7.7M      100+  Free     0           Teen
# 10831      38  9.8M    5,000+  Free     0       Everyone
# 10835       0  9.6M       10+  Free     0       Everyone
# 10838       3  9.5M    1,000+  Free     0       Everyone
#
#                                 Genres        Last Updated Current Ver  \
# 23     Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 113                             Beauty  September 20, 2017         8.0
# 123                             Beauty       July 23, 2018         1.3
# 126                             Beauty       July 17, 2018        1.15
# 129                             Beauty      August 8, 2017         2.0
# ...                                ...                 ...         ...
# 10824                          Medical       July 31, 2018       2.2.2
# 10825                           Social    February 2, 2018         1.0
# 10831                Maps & Navigation       June 13, 2018   2.0.148.0
# 10835                         Business  September 29, 2016       1.1.5
# 10838                          Medical    January 20, 2017         1.0
#
#       Android Ver
# 23     4.1 and up
# 113    3.0 and up
# 123    4.1 and up
# 126    4.1 and up
# 129    2.3 and up
# ...           ...
# 10824  4.4 and up
# 10825  4.0 and up
# 10831  4.0 and up
# 10835  4.0 and up
# 10838  2.2 and up
#
# [1474 rows x 13 columns]

# %%
google_playstore.fillna({'Rating': 1}, inplace = True)

# %%
google_playstore.fillna({'Type': 'Free'}, inplace = True)

# %%
google_playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     1.0       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10840 rows x 13 columns]

# %%
google_playstore['Installs'] = google_playstore['Installs'].str.replace(',', '').str.replace('+', '').str.strip().astype('int64')

# %%
google_playstore['Installs'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10840 entries, 0 to 10840
# Series name: Installs
# Non-Null Count  Dtype
# --------------  -----
# 10840 non-null  int64
# dtypes: int64(1)
# memory usage: 169.4 KB

# %%
google_playstore['Installs'].describe()
# Out:
# count    1.084000e+04
# mean     1.546434e+07
# std      8.502936e+07
# min      0.000000e+00
# 25%      1.000000e+03
# 50%      1.000000e+05
# 75%      5.000000e+06
# max      1.000000e+09
# Name: Installs, dtype: float64

# %%
google_playstore[google_playstore['Rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
google_playstore[google_playstore['Rating']==1.0]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     1.0
# 113              Wrinkles and rejuvenation               BEAUTY     1.0
# 123                 Manicure - nail design               BEAUTY     1.0
# 126           Skin Care and Natural Beauty               BEAUTY     1.0
# 129    Secrets of beauty, youth and health               BEAUTY     1.0
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     1.0
# 10825                   Naruto & Boruto FR               SOCIAL     1.0
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     1.0
# 10835                             FR Forms             BUSINESS     1.0
# 10838               Parkinson Exercices FR              MEDICAL     1.0
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# 23         61  7.0M    100000  Free     0       Everyone
# 113       182  5.7M    100000  Free     0   Everyone 10+
# 123       119  3.7M     50000  Free     0       Everyone
# 126       654  7.4M    100000  Free     0           Teen
# 129        77  2.9M     10000  Free     0     Mature 17+
# ...       ...   ...       ...   ...   ...            ...
# 10824      67   82M     10000  Free     0       Everyone
# 10825       7  7.7M       100  Free     0           Teen
# 10831      38  9.8M      5000  Free     0       Everyone
# 10835       0  9.6M        10  Free     0       Everyone
# 10838       3  9.5M      1000  Free     0       Everyone
#
#                                 Genres        Last Updated Current Ver  \
# 23     Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 113                             Beauty  September 20, 2017         8.0
# 123                             Beauty       July 23, 2018         1.3
# 126                             Beauty       July 17, 2018        1.15
# 129                             Beauty      August 8, 2017         2.0
# ...                                ...                 ...         ...
# 10824                          Medical       July 31, 2018       2.2.2
# 10825                           Social    February 2, 2018         1.0
# 10831                Maps & Navigation       June 13, 2018   2.0.148.0
# 10835                         Business  September 29, 2016       1.1.5
# 10838                          Medical    January 20, 2017         1.0
#
#       Android Ver
# 23     4.1 and up
# 113    3.0 and up
# 123    4.1 and up
# 126    4.1 and up
# 129    2.3 and up
# ...           ...
# 10824  4.4 and up
# 10825  4.0 and up
# 10831  4.0 and up
# 10835  4.0 and up
# 10838  2.2 and up
#
# [1490 rows x 13 columns]

# %%
ind_review = google_playstore[google_playstore['Reviews'] == '0'].index
ind_review
# Out:
# Index([  478,   479,   621,   623,   627,   628,   630,   632,   635,   639,
#        ...
#        10734, 10736, 10748, 10762, 10772, 10773, 10774, 10798, 10822, 10835],
#       dtype='int64', length=596)

# %%
google_playstore.loc[ind_review, 'Rating'] = 0

# %%
google_playstore[google_playstore['Reviews'] == '0']
# Out:
#                                                    App            Category  \
# 478                                  Truth or Dare Pro              DATING
# 479    Private Dating, Hide App- Blue for PrivacyHider              DATING
# 621                                 Dating White Girls              DATING
# 623                                       Geeks Dating              DATING
# 627                                 CAM5678 Video Chat              DATING
# ...                                                ...                 ...
# 10773                                         FQ India           LIFESTYLE
# 10774                                          Miss FQ  NEWS_AND_MAGAZINES
# 10798                             Word Search Tab 1 FR              FAMILY
# 10822                                        PLMGSS FR        PRODUCTIVITY
# 10835                                         FR Forms            BUSINESS
#
#        Rating Reviews   Size  Installs  Type  Price Content Rating  \
# 478       0.0       0    20M        50  Paid  $1.49           Teen
# 479       0.0       0    18k       100  Paid  $2.99       Everyone
# 621       0.0       0   3.6M        50  Free      0     Mature 17+
# 623       0.0       0    13M        50  Free      0     Mature 17+
# 627       0.0       0    39M       500  Free      0     Mature 17+
# ...       ...     ...    ...       ...   ...    ...            ...
# 10773     0.0       0   8.9M        10  Free      0       Everyone
# 10774     0.0       0    36M        10  Free      0       Everyone
# 10798     0.0       0  1020k        50  Paid  $1.04       Everyone
# 10822     0.0       0   3.1M        10  Free      0       Everyone
# 10835     0.0       0   9.6M        10  Free      0       Everyone
#
#                  Genres        Last Updated Current Ver   Android Ver
# 478              Dating   September 1, 2017         1.0    4.0 and up
# 479              Dating       July 25, 2017       1.0.1    4.0 and up
# 621              Dating       July 20, 2018         1.0    4.0 and up
# 623              Dating       July 10, 2018         1.0    4.1 and up
# 627              Dating       July 13, 2018       5.5.8  4.0.3 and up
# ...                 ...                 ...         ...           ...
# 10773         Lifestyle       July 31, 2018       7.2.2    4.1 and up
# 10774  News & Magazines       April 5, 2018         3.8    4.4 and up
# 10798            Puzzle    February 6, 2012         1.1    3.0 and up
# 10822      Productivity    December 1, 2017           1    4.4 and up
# 10835          Business  September 29, 2016       1.1.5    4.0 and up
#
# [596 rows x 13 columns]

# %%
google_playstore['Reviews'].str.isalpha().any()
# Out:
# False

# %%
google_playstore['Reviews'] = google_playstore['Reviews'].astype('int64')

# %%
google_playstore['Last Updated'] = pd.to_datetime(google_playstore['Last Updated'])

# %%
google_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 1.4+ MB

# %%
google_playstore.loc[ind_review, 'Rating']  # df.loc(ind, column) = value -update
# Out:
# 478      0.0
# 479      0.0
# 621      0.0
# 623      0.0
# 627      0.0
#         ...
# 10773    0.0
# 10774    0.0
# 10798    0.0
# 10822    0.0
# 10835    0.0
# Name: Rating, Length: 596, dtype: float64

# %%
sns.boxplot(x=google_playstore['Rating'])
plt.show()

# %%
google_playstore['Rating'].skew()
# Out:
# -1.7546710508506222

# %%
sns.histplot(x=google_playstore['Rating'], bins= 10)
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.kdeplot(x=google_playstore['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
google_playstore[google_playstore['Android Ver'].isnull()]
# Out:
#                          App         Category  Rating  Reviews  Size  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4      230   11M
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5      189  2.1M
#
#       Installs  Type  Price Content Rating           Genres Last Updated  \
# 4453      1000  Paid  $1.49       Everyone  Personalization   2018-07-20
# 4490     10000  Free      0       Everyone  Personalization   2018-03-27
#
#      Current Ver Android Ver
# 4453         4.4         NaN
# 4490         1.1         NaN

# %%
# android ver
google_playstore['Android Ver'].value_counts()
# Out:
# Android Ver
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: count, dtype: int64

# %%
andver_mode = google_playstore['Android Ver'].mode()[0]

# %%
google_playstore.fillna({'Android Ver': andver_mode}, inplace = True)

# %%
google_playstore[google_playstore['Category'].str.contains('PERSONALIZATION', case = False)]
# Out:
#                                                    App         Category  \
# 3352                                     Nova Launcher  PERSONALIZATION
# 3353                                   Funny Ringtones  PERSONALIZATION
# 3354                     ZEDGE™ Ringtones & Wallpapers  PERSONALIZATION
# 3355                    XOS - Launcher,Theme,Wallpaper  PERSONALIZATION
# 3356                        3D Live Neon Weed Launcher  PERSONALIZATION
# ...                                                ...              ...
# 10710                                    Stylish Fonts  PERSONALIZATION
# 10722                   Launcher Theme for LG K10 2018  PERSONALIZATION
# 10733                           FP Click sound changer  PERSONALIZATION
# 10747                             FP Charging Daydream  PERSONALIZATION
# 10788  Fountain Live Wallpaper HD – Dubai Wallpaper 3D  PERSONALIZATION
#
#        Rating  Reviews                Size   Installs  Type Price  \
# 3352      4.6  1121805  Varies with device   50000000  Free     0
# 3353      4.4     7146                 14M    1000000  Free     0
# 3354      4.6  6466641  Varies with device  100000000  Free     0
# 3355      4.6    49657                8.7M    5000000  Free     0
# 3356      4.5     1724                 21M     100000  Free     0
# ...       ...      ...                 ...        ...   ...   ...
# 10710     3.8   153176                4.3M   10000000  Free     0
# 10722     4.0      649                 11M     100000  Free     0
# 10733     3.5      178                1.4M      10000  Free     0
# 10747     3.5       96                3.8M       5000  Free     0
# 10788     1.0        1                 20M        500  Free     0
#
#       Content Rating           Genres Last Updated         Current Ver  \
# 3352        Everyone  Personalization   2018-05-14  Varies with device
# 3353    Everyone 10+  Personalization   2018-02-02                 1.1
# 3354            Teen  Personalization   2018-07-19  Varies with device
# 3355        Everyone  Personalization   2018-08-06          3.6.21_pre
# 3356      Mature 17+  Personalization   2018-06-26             5.34.10
# ...              ...              ...          ...                 ...
# 10710       Everyone  Personalization   2018-08-07                1.17
# 10722       Everyone  Personalization   2017-03-30                 1.0
# 10733       Everyone  Personalization   2015-12-26                 1.0
# 10747       Everyone  Personalization   2015-11-23                 2.0
# 10788       Everyone  Personalization   2018-04-13                 1.0
#
#               Android Ver
# 3352   Varies with device
# 3353           4.0 and up
# 3354   Varies with device
# 3355           4.4 and up
# 3356         4.0.3 and up
# ...                   ...
# 10710        4.0.3 and up
# 10722        2.3.3 and up
# 10733          1.6 and up
# 10747          4.2 and up
# 10788          4.1 and up
#
# [392 rows x 13 columns]

# %%
google_playstore[google_playstore['Android Ver'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
google_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10840 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 1.4+ MB

# %%
# current ver
google_playstore['Current Ver'].value_counts()
# Out:
# Current Ver
# Varies with device    1459
# 1.0                    809
# 1.1                    264
# 1.2                    178
# 2.0                    151
#                       ...
# 5.44.1                   1
# 7.16.8                   1
# 04.08.00                 1
# 2.10.06                  1
# 2.0.148.0                1
# Name: count, Length: 2831, dtype: int64

# %%
currver_mode = google_playstore['Current Ver'].mode()[0]

# %%
currver_mode
# Out:
# 'Varies with device'

# %%
google_playstore.fillna({'Current Ver': currver_mode}, inplace = True)

# %%
# Reviews
google_playstore.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
google_playstore[google_playstore['Reviews']=='0']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# size
google_playstore['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10840, dtype: object

# %%
# installs
google_playstore['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10840, dtype: int64

# %%
google_playstore['Installs'].nunique()
# Out:
# 20

# %%
google_playstore['Installs'].value_counts()
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           907
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
ax = sns.countplot(x=google_playstore['Installs'])
for container in ax.containers: 
    ax.bar_label(container, fmt = '%.0f', label_type = 'edge', padding = 3)
plt.xticks(rotation = 70)
plt.ylabel("No of apps installed")
plt.show()

# %%
# Type
google_playstore['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
google_playstore['Type'].isnull().sum()
# Out:
# 0

# %%
google_playstore[google_playstore['Type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# google_playstore[google_playstore['Type'] == 'NaN'] won't work as nan == nan even itself, so we can't compare.

# %%
google_playstore['Type'].value_counts().plot(kind='pie', autopct = "%0.0f%%" )
# Out:
# <Axes: ylabel='count'>

# %%
ax = sns.countplot(x=google_playstore['Type'])
for container in ax.containers:
    ax.bar_label(container, fmt="%.0f", label_type= 'edge', padding = 2)
plt.ylabel("Number of apps")
plt.show()

# %%
# Price
google_playstore['Price'].nunique()
# Out:
# 92

# %%
google_playstore['Price'].isnull().sum()
# Out:
# 0

# %%
google_playstore['Price'].value_counts()
# Out:
# Price
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %%
google_playstore['Price'] = google_playstore['Price'].str.replace('$', '').str.strip().astype('float64')

# %%
google_playstore['Price'].sample()
# Out:
# 5636    0.0
# Name: Price, dtype: float64

# %%
# Content Rating
google_playstore['Content Rating'].nunique()
# Out:
# 6

# %%
google_playstore['Content Rating'].isnull().sum()
# Out:
# 0

# %%
google_playstore[google_playstore['Content Rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(x= google_playstore['Content Rating'])
for container in ax.containers:
    ax.bar_label(container, fmt = "%.0f", label_type= 'edge', padding=2)
plt.ylabel("No of apps")
plt.show()

# %%
plt.figure(figsize= (6,6))
google_playstore['Content Rating'].value_counts().plot(kind = 'pie', autopct = '%0.0f%%')
plt.show()

# %%
# Genres
google_playstore['Genres'].isnull().sum()
# Out:
# 0

# %%
google_playstore['Genres'].nunique()
# Out:
# 119

# %%
# sns.countplot(x= google_playstore['Genres'])

# %%
# Last Updated
google_playstore['Last Updated'].isnull().sum()
# Out:
# 0

# %%
google_playstore['Last Updated'].nunique()
# Out:
# 1377

# %%
# Current Ver
google_playstore['Current Ver'].isnull().sum()
# Out:
# 0

# %%
google_playstore[google_playstore['Current Ver'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# Android Ver
google_playstore['Android Ver'].isnull().sum()
# Out:
# 0

# %%
google_playstore[google_playstore['Android Ver'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
google_playstore['Android Ver'].nunique()
# Out:
# 33

# %%
google_playstore['Android Ver'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Android Ver'>

# %%
google_playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# 0         4.1      159                 19M     10000  Free    0.0
# 1         3.9      967                 14M    500000  Free    0.0
# 2         4.7    87510                8.7M   5000000  Free    0.0
# 3         4.5   215644                 25M  50000000  Free    0.0
# 4         4.3      967                2.8M    100000  Free    0.0
# ...       ...      ...                 ...       ...   ...    ...
# 10836     4.5       38                 53M      5000  Free    0.0
# 10837     5.0        4                3.6M       100  Free    0.0
# 10838     1.0        3                9.5M      1000  Free    0.0
# 10839     4.5      114  Varies with device      1000  Free    0.0
# 10840     4.5   398307                 19M  10000000  Free    0.0
#
#       Content Rating                     Genres Last Updated  \
# 0           Everyone               Art & Design   2018-01-07
# 1           Everyone  Art & Design;Pretend Play   2018-01-15
# 2           Everyone               Art & Design   2018-08-01
# 3               Teen               Art & Design   2018-06-08
# 4           Everyone    Art & Design;Creativity   2018-06-20
# ...              ...                        ...          ...
# 10836       Everyone                  Education   2017-07-25
# 10837       Everyone                  Education   2018-07-06
# 10838       Everyone                    Medical   2017-01-20
# 10839     Mature 17+          Books & Reference   2015-01-19
# 10840       Everyone                  Lifestyle   2018-07-25
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10840 rows x 13 columns]

# %%
google_playstore[google_playstore.duplicated(keep=False)].sort_values(by='App')
# Out:
#                                                     App            Category  \
# 1393                              10 Best Foods for You  HEALTH_AND_FITNESS
# 1407                              10 Best Foods for You  HEALTH_AND_FITNESS
# 2543                         1800 Contacts - Lens Store             MEDICAL
# 2322                         1800 Contacts - Lens Store             MEDICAL
# 2256                         2017 EMRA Antibiotic Guide             MEDICAL
# ...                                                 ...                 ...
# 3063  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3055  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3103                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 3202                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 3118                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
#
#       Rating  Reviews                Size  Installs  Type  Price  \
# 1393     4.0     2490                3.8M    500000  Free   0.00
# 1407     4.0     2490                3.8M    500000  Free   0.00
# 2543     4.7    23160                 26M   1000000  Free   0.00
# 2322     4.7    23160                 26M   1000000  Free   0.00
# 2256     4.4       12                3.8M      1000  Paid  16.99
# ...      ...      ...                 ...       ...   ...    ...
# 3063     4.4   133833                 34M  10000000  Free   0.00
# 3055     4.4   133833                 34M  10000000  Free   0.00
# 3103     4.2   219848  Varies with device  50000000  Free   0.00
# 3202     4.2   219848  Varies with device  50000000  Free   0.00
# 3118     4.2   219848  Varies with device  50000000  Free   0.00
#
#      Content Rating            Genres Last Updated         Current Ver  \
# 1393   Everyone 10+  Health & Fitness   2017-02-17                 1.9
# 1407   Everyone 10+  Health & Fitness   2017-02-17                 1.9
# 2543       Everyone           Medical   2018-07-27               7.4.1
# 2322       Everyone           Medical   2018-07-27               7.4.1
# 2256       Everyone           Medical   2017-01-27               1.0.5
# ...             ...               ...          ...                 ...
# 3063   Everyone 10+            Sports   2018-07-25              6.17.2
# 3055   Everyone 10+            Sports   2018-07-25              6.17.2
# 3103       Everyone    Travel & Local   2018-08-02  Varies with device
# 3202       Everyone    Travel & Local   2018-08-02  Varies with device
# 3118       Everyone    Travel & Local   2018-08-02  Varies with device
#
#              Android Ver
# 1393        2.3.3 and up
# 1407        2.3.3 and up
# 2543          5.0 and up
# 2322          5.0 and up
# 2256        4.0.3 and up
# ...                  ...
# 3063          4.4 and up
# 3055          4.4 and up
# 3103  Varies with device
# 3202  Varies with device
# 3118  Varies with device
#
# [893 rows x 13 columns]

# %%
google_playstore.drop_duplicates(inplace = True)

# %%
google_playstore.duplicated().any()
# Out:
# False

# %%
google_playstore.describe()
# Out:
#              Rating       Reviews      Installs         Price  \
# count  10357.000000  1.035700e+04  1.035700e+04  10357.000000
# mean       3.679695  4.059046e+05  1.415776e+07      1.030800
# min        0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        3.700000  3.200000e+01  1.000000e+03      0.000000
# 50%        4.200000  1.680000e+03  1.000000e+05      0.000000
# 75%        4.500000  4.641600e+04  1.000000e+06      0.000000
# max        5.000000  7.815831e+07  1.000000e+09    400.000000
# std        1.354984  2.696778e+06  8.023955e+07     16.278625
#
#                         Last Updated
# count                          10357
# mean   2017-11-14 09:25:19.320266496
# min              2010-05-21 00:00:00
# 25%              2017-09-03 00:00:00
# 50%              2018-05-20 00:00:00
# 75%              2018-07-19 00:00:00
# max              2018-08-08 00:00:00
# std                              NaN

# %%
google_playstore[google_playstore['Price']==400.0]
# Out:
#                            App   Category  Rating  Reviews  Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6      275  7.3M     10000
#
#       Type  Price Content Rating     Genres Last Updated Current Ver  \
# 4367  Paid  400.0       Everyone  Lifestyle   2018-05-03       1.0.1
#
#      Android Ver
# 4367  4.1 and up

# %%
google_playstore.to_csv('google_playstore_clean.csv')
